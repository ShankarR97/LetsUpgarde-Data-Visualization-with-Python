# %% [markdown]
# # LetsUpgrade - Day1 Assignment Task

# %% [markdown]
# # Question 1

# %% [markdown]
# # plot a line plot between a and b:
#
# a=np.arange(40,50)
# b=np.arange(50,60)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from numpy.random import randn, randint, uniform, sample
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.arange(40,50)
y=np.arange(50,60)

# %%
plt.plot(x,y,'go--', linewidth=1, markersize=5)
plt.title('Line Plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0,0.5,'y-axis')

# %%
x = np.arange(1,11)
y = 3 * x + 5

# %%
x = np.arange(1,11)
y = 3 * x + 5
plt.title("Line plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.plot(x,y)

# %% [markdown]
# # Question 2

# %% [markdown]
# Plot a line plot showing the sales trend in company 1 and 2:
#
#
# days = [1,2,3,4,5,6,7] #days of d week
# sales_1 = [160,150,140,145,175,165,180] #sales of company1
# sales_2 = [70,90,160,150,140,145,175]  #sales of company2

# %%
days = [1,2,3,4,5,6,7] #days of d week
sales_1 = [160,150,140,145,175,165,180] #sales of company1
sales_2 = [70,90,160,150,140,145,175]  #sales of company2

plt.figure(figsize = (6,5), dpi=150)
plt.plot(days, sales_1)
plt.plot(days,sales_2)

plt.title('Sales per day in USD', fontsize=10, color='red')

plt.xlabel('Days of the Week')

plt.ylabel('Sales')

plt.grid()

plt.show()

# %% [markdown]
# # Question 3

# %% [markdown]
# **Create a 3 by 3 subplots:
# multiple plots
#
# x = [1,2,3,4]
# y1 = [4,3,2,1]
# y2 = [10,20,30,40]
# y3 = [40,30,20,10]
# y4 = [1,2,1,2]
# y5 = [40,70,90,70]

# %%
x = [1,2,3,4]
y1 = [4,3,2,1]
y2 = [10,20,30,40]
y3 = [40,30,20,10]
y4 = [1,2,1,2]
y5 = [40,70,90,70]

ax1=plt.subplot2grid((3,3), (0,0), colspan=3) 
ax1.plot(x,y1)


ax2=plt.subplot2grid((3,3), (1,0), colspan=2)
ax2.plot(x, y2)

ax3=plt.subplot2grid((3,3), (1,2), rowspan=2)
ax3.plot(x,y3)


ax4=plt.subplot2grid((3,3), (2,0))
ax4.plot(x,y4)

plt.grid()
plt.show()
